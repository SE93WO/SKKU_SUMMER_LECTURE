# %%
# !pip install msgpack
# !pip install autogluon

# %% [markdown]
# # 실습 2 - AutoGluon 모델 학습과 해석
#
# **서울 공공자전거(따릉이) 데이터를 활용한 예측 모델 구축**
#
# 앞선 실습에서는 원본 데이터를 모델이 처리 가능한 수치로 변환하는 **전처리**를 다루었다. 본 실습에서는 해당 데이터로 **예측 모델을 학습**하고 결과를 해석한다.
#
# 본 실습에서 확인할 사항은 다음과 같다.
#
# 1. `fit()` 단일 명령으로 다수의 모델이 자동으로 학습된다.
# 2. AutoGluon은 문제 유형(회귀/분류)을 자동으로 판별한다.
# 3. 다수의 모델을 결합한 **앙상블**이 개별 모델보다 우수하다.
# 4. 어떤 변수가 예측에 중요한지 확인할 수 있다.
#
# > 전처리(`fit_transform`)는 별도로 호출하지 않는다. `fit()` 내부에서 자동으로 수행되기 때문이다.

# %% [markdown]
# ---
# ## 0. 환경 준비와 데이터 불러오기
#
# 필요한 라이브러리를 불러오고, 앞선 실습과 동일하게 따릉이 데이터를 불러온다.

# %%
import sys
sys.path = [p for p in sys.path if ".local" not in p]
sys.path.insert(0, "/home/work/.local/lib/python3.10/site-packages")
import pandas as pd

df = pd.read_csv("SeoulBikeData.csv", encoding="latin-1")
df["Date"] = pd.to_datetime(df["Date"], format="%d/%m/%Y")

print("데이터 크기:", df.shape)
df.head(3)
# Out:
# 데이터 크기: (8760, 14)
#         Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-12-01                254     0             -5.2           37
# 1 2017-12-01                204     1             -5.5           38
# 2 2017-12-01                173     2             -6.0           39
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
#
#   Functioning Day
# 0             Yes
# 1             Yes
# 2             Yes

# %% [markdown]
# ---
# ## 1. 학습용 데이터와 평가용 데이터 분할
#
# 모델 구축 시 데이터를 두 부분으로 분할한다.
#
# - **학습용(train)**: 모델 학습에 사용한다.
# - **평가용(test)**: 학습에 사용하지 않고 별도로 보관하였다가, 완성된 모델의 성능 측정에 사용한다.
#
# 이와 같이 분할하는 이유는, 모델이 이미 학습한 데이터로 성능을 측정할 경우 실제보다 높게 측정되기 때문이다. 학습에 사용하지 않은 데이터에 대한 예측 성능을 확인해야 실제 성능(일반화 성능)을 파악할 수 있다.
#
# 아래 코드는 전체의 80%를 학습용, 20%를 평가용으로 무작위 분할한다.
#
# 여기서 분할하는 것은 최종 **평가용(test)** 이다. 이와 별개로, AutoGluon은 학습 과정에서 모델 비교를 위한 **검증용(validation)** 데이터를 학습용 내부에서 자동으로 분할한다. 즉, 연구자는 평가용만 분할하면 되며, 학습 과정의 검증 분할은 AutoGluon이 자동으로 처리한다.

# %%
train_data = df.sample(frac=0.8, random_state=42)
test_data = df.drop(train_data.index)

print("학습용:", train_data.shape)
print("평가용:", test_data.shape)
# Out:
# 학습용: (7008, 14)
# 평가용: (1752, 14)

# %%
ratio = lambda d: d["Seasons"].value_counts(
            normalize=True).round(3) * 100

pd.DataFrame({
    "학습용 비율(%)": ratio(train_data),
    "평가용 비율(%)": ratio(test_data),
})
# Out:
#          학습용 비율(%)  평가용 비율(%)
# Seasons
# Autumn        24.8       25.6
# Spring        25.3       24.9
# Summer        25.3       24.9
# Winter        24.7       24.5

# %% [markdown]
# ---
# ## 2. 모델 학습: `fit()`
#
# 모델을 학습한다. 방법은 단순하다.
#
# - `TabularPredictor(label="Rented Bike Count")` : 예측 대상을 지정한다. `label`은 예측 목표 컬럼이며, 여기서는 대여량이다.
# - `.fit(train_data)` : 학습용 데이터로 모델을 학습한다.
#
# 이 단일 명령 내에서 전처리, 다수 모델의 학습, 앙상블 구성이 모두 자동으로 수행된다.

# %%
from autogluon.tabular import TabularPredictor
predictor = TabularPredictor(label="Rented Bike Count").fit(train_data)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20260713_072831"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #191-Ubuntu SMP Fri Feb 2 13:55:07 UTC 2024
# CPU Count:          18
# Pytorch Version:    2.9.1+cu128
# CUDA Version:       12.8
# GPU Memory:         GPU 0: 24.00/24.00 GB
# Total GPU Memory:   Free: 24.00 GB, Allocated: 0.00 GB, Total: 24.00 GB
# GPU Count:          1
# Memory Avail:       946.21 GB / 1007.45 GB (93.9%)
# Disk Space Avail:   420215.08 GB / 1080179.50 GB (38.9%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='extreme'  : New in v1.5: The state-of-the-art for tabular data. Massively better than 'best' on datasets <100000 samples by using new Tabular Foundation Models (TFMs) meta-learned on https://tabarena.ai: TabPFNv2, TabICL, Mitra, TabDPT, and TabM. Requires a GPU and `pip install autogluon.tabular[tabarena]` to install TabPFN, TabICL, and TabDPT.
# 	presets='best'     : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='best_v150': New in v1.5: Better quality than 'best' and 5x+ faster to train. Give it a try!
# 	presets='high'     : Strong accuracy with fast inference speed.
# 	presets='high_v150': New in v1.5: Better quality than 'high' and 5x+ faster to train. Give it a try!
# 	presets='good'     : Good accuracy with very fast inference speed.
# 	presets='medium'   : Fast training time, ideal for initial prototyping.
# Using hyperparameters preset: hyperparameters='default'
# Beginning AutoGluon training ...
# AutoGluon will save models to "/workspace/SKKU/AutogluonModels/ag-20260713_072831"
# Train Data Rows:    7008
# Train Data Columns: 13
# Label Column:       Rented Bike Count
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == int and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (3556, 0, 706.56436, 644.72501)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    968922.33 MB
# 	Train Data (Original)  Memory Usage: 1.80 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('datetime', []) : 1 | ['Date']
# 		('float', [])    : 6 | ['Temperature(°C)', 'Wind speed (m/s)', 'Dew point temperature(°C)', 'Solar Radiation (MJ/m2)', 'Rainfall(mm)', ...]
# 		('int', [])      : 3 | ['Hour', 'Humidity(%)', 'Visibility (10m)']
# 		('object', [])   : 3 | ['Seasons', 'Holiday', 'Functioning Day']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])             : 1 | ['Seasons']
# 		('float', [])                : 6 | ['Temperature(°C)', 'Wind speed (m/s)', 'Dew point temperature(°C)', 'Solar Radiation (MJ/m2)', 'Rainfall(mm)', ...]
# 		('int', [])                  : 3 | ['Hour', 'Humidity(%)', 'Visibility (10m)']
# 		('int', ['bool'])            : 2 | ['Holiday', 'Functioning Day']
# 		('int', ['datetime_as_int']) : 5 | ['Date', 'Date.year', 'Date.month', 'Date.day', 'Date.dayofweek']
# 	0.1s = Fit runtime
# 	13 features in original data used to generate 17 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.77 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.08s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 6307, Val Rows: 701
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}],
# 	'XGB': [{}],
# 	'FASTAI': [{}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# Fitting 9 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT ...
# 	Warning: Exception caused LightGBMXT to fail during training... Skipping this model.
#
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2201, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2085, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1081, in fit
#     kwargs = self._preprocess_fit_args(**kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 706, in _preprocess_fit_args
#     kwargs = self._preprocess_fit_resources(**kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 969, in _preprocess_fit_resources
#     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 904, in _calculate_total_resources
#     assert system_num_cpus >= num_cpus
# AssertionError
# Fitting model: LightGBM ...
# 	Warning: Exception caused LightGBM to fail during training... Skipping this model.
#
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2201, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2085, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1081, in fit
#     kwargs = self._preprocess_fit_args(**kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 706, in _preprocess_fit_args
#     kwargs = self._preprocess_fit_resources(**kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 969, in _preprocess_fit_resources
#     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 904, in _calculate_total_resources
#     assert system_num_cpus >= num_cpus
# AssertionError
# Fitting model: RandomForestMSE ...
# 	Fitting with cpus=18, gpus=0, mem=0.0/946.2 GB
# 	-159.4233	 = Validation score   (-root_mean_squared_error)
# 	0.76s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost ...
# 	Warning: Exception caused CatBoost to fail during training... Skipping this model.
#
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2201, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2085, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1081, in fit
#     kwargs = self._preprocess_fit_args(**kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 706, in _preprocess_fit_args
#     kwargs = self._preprocess_fit_resources(**kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 969, in _preprocess_fit_resources
#     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 904, in _calculate_total_resources
#     assert system_num_cpus >= num_cpus
# AssertionError
# Fitting model: ExtraTreesMSE ...
# 	Fitting with cpus=18, gpus=0, mem=0.0/945.9 GB
# 	-157.276	 = Validation score   (-root_mean_squared_error)
# 	0.48s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	Warning: Exception caused NeuralNetFastAI to fail during training... Skipping this model.
#
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2201, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2085, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1081, in fit
#     kwargs = self._preprocess_fit_args(**kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 706, in _preprocess_fit_args
#     kwargs = self._preprocess_fit_resources(**kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 969, in _preprocess_fit_resources
#     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 904, in _calculate_total_resources
#     assert system_num_cpus >= num_cpus
# AssertionError
# Fitting model: XGBoost ...
# 	Warning: Exception caused XGBoost to fail during training... Skipping this model.
#
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2201, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2085, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1081, in fit
#     kwargs = self._preprocess_fit_args(**kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 706, in _preprocess_fit_args
#     kwargs = self._preprocess_fit_resources(**kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 969, in _preprocess_fit_resources
#     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 904, in _calculate_total_resources
#     assert system_num_cpus >= num_cpus
# AssertionError
# Fitting model: NeuralNetTorch ...
# 	Warning: Exception caused NeuralNetTorch to fail during training... Skipping this model.
#
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2201, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2085, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1081, in fit
#     kwargs = self._preprocess_fit_args(**kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 706, in _preprocess_fit_args
#     kwargs = self._preprocess_fit_resources(**kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 969, in _preprocess_fit_resources
#     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 904, in _calculate_total_resources
#     assert system_num_cpus >= num_cpus
# AssertionError
# Fitting model: LightGBMLarge ...
# 	Warning: Exception caused LightGBMLarge to fail during training... Skipping this model.
#
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2201, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2085, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1081, in fit
#     kwargs = self._preprocess_fit_args(**kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 706, in _preprocess_fit_args
#     kwargs = self._preprocess_fit_resources(**kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 969, in _preprocess_fit_resources
#     return self._calculate_total_resources(silent=silent, total_resources=total_resources, parallel_hpo=parallel_hpo, **kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 904, in _calculate_total_resources
#     assert system_num_cpus >= num_cpus
# AssertionError
# Fitting model: WeightedEnsemble_L2 ...
# 	Fitting 1 model on all data | Fitting with cpus=18, gpus=0, mem=0.0/945.8 GB
# 	Ensemble Weights: {'ExtraTreesMSE': 0.562, 'RandomForestMSE': 0.438}
# 	-153.9669	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2.71s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 7227.8 rows/s (701 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/workspace/SKKU/AutogluonModels/ag-20260713_072831")

# %% [markdown]
# #### 학습 로그에서 확인할 사항
#
# 1. **`AutoGluon infers your prediction problem is: 'regression'`**
#    → 대여량이 수치형이고 값이 다양하므로, AutoGluon이 **회귀 문제**로 판별하였다. (예측 대상이 '고장/정상'과 같은 값이었다면 분류로 판별한다.)
#
# 2. **`Fitting model: ...`** 의 반복
#    → LightGBM, RandomForest, CatBoost, 신경망(NeuralNet) 등 **다양한 모델이 순차적으로 학습**된다.
#
# 3. **`Fitting model: WeightedEnsemble_L2`**
#    → 최종적으로 개별 모델들을 결합한 **앙상블 모델**이 생성된다.

# %% [markdown]
# ---
# ## 3. 성능 확인: `leaderboard()`
#
# 학습된 모델들의 성능을 비교한다. `leaderboard(test_data)`는 평가용 데이터에 대한 각 모델의 성능을 측정하여 순위표로 출력한다.

# %%
leaderboard = predictor.leaderboard(test_data)
leaderboard

# %% [markdown]
# - **`model`**: 모델 이름이다. `WeightedEnsemble`이 앞서 설명한 앙상블 모델이다.
# - **`score_test`**: 평가용 데이터에 대한 성능이다. 회귀에서는 점수가 **0에 가까울수록(음수의 절댓값이 작을수록) 우수하다.** AutoGluon은 값이 클수록 우수하도록 부호를 통일하므로, 목록의 **최상단 행이 가장 우수한 모델**이다.
# - 통상 최상단은 **`WeightedEnsemble`** 이다. 즉, 다수의 모델을 결합한 앙상블이 개별 모델보다 우수함을 확인할 수 있다.
#
# > `score`가 음수인 이유: AutoGluon은 '클수록 우수함'으로 기준을 통일하기 위해, 오차 지표(작을수록 우수)에 음수 부호를 적용한다. 따라서 -138이 -145보다 우수한 성능이다.

# %% [markdown]
# ---
# ## 4. 예측: `predict()`
#
# 완성된 모델로 평가용 데이터의 대여량을 예측하고 실제 값과 비교한다. `predict()`는 가장 우수한 모델(앙상블)을 자동으로 사용한다.

# %%
predictions = predictor.predict(test_data)

# 실제 값과 예측 값을 나란히 비교
compare = pd.DataFrame({
    "실제 대여량": test_data["Rented Bike Count"].values,
    "예측 대여량": predictions.values.round(0)
})
compare.head(10)

# %% [markdown]
# 실제 값과 예측 값의 근접 여부를 확인한다. 완전히 일치하지는 않으나, 대체로 근접한 값을 예측함을 확인할 수 있다.

# %% [markdown]
# ---
# ## 5. 연구자가 조절하는 학습 설정
#
# 지금까지는 `fit()`을 **기본 설정**으로 실행하였다. AutoGluon은 개별 모델의 세부 하이퍼파라미터(학습률, 트리 깊이 등)를 연구자가 직접 조정할 필요가 없도록 설계되어 있다. 대신, 연구자는 다음 **세 가지 상위 설정**으로 학습의 방향을 결정한다.
#
# | 설정 | 역할 | 값의 예 |
# |---|---|---|
# | `presets` | 성능과 학습 시간의 균형 | `best_quality`(고성능·느림) / `medium_quality`(빠름) |
# | `time_limit` | 학습에 사용할 최대 시간(초) | `time_limit=600` (10분) |
# | `eval_metric` | 성능 판단 기준 | 회귀: `rmse`, `mae` / 분류: `accuracy`, `f1` |
#
# 이 중 `eval_metric`은 **연구 목적에 따라 결정**된다. 무엇을 정확히 예측해야 하는가는 기계가 아니라 연구자가 판단하는 영역이다.

# %% [markdown]
# #### 예시: 평가지표(`eval_metric`) 변경 후 학습
#
# 기본값 대신 `mae`(평균 절대 오차)를 평가지표로 지정하여 재학습한다. `mae`는 예측이 실제 값에서 평균적으로 벗어난 정도를 절댓값으로 측정하는 지표이다. (학습 시간 단축을 위해 `time_limit`을 짧게 지정한다.)

# %%
predictor_mae = TabularPredictor(
    label="Rented Bike Count",
    eval_metric="mae"              # 평가지표를 MAE로 지정 (기본값은 RMSE)
).fit(train_data)  # 학습 시간을 120초로 제한

predictor_mae.leaderboard(test_data)

# %% [markdown]
# `eval_metric` 열이 `mae`로 변경되었음을 확인할 수 있다. 평가 기준이 달라지면 모델의 순위나 최적 모델이 달라질 수 있다. 즉, 어떤 기준으로 우수한 모델을 선정하는가에 따라 결과가 달라진다.

# %% [markdown]
# #### 성능 우선 설정(`presets`)
#
# 더 높은 정확도가 필요한 경우 `presets="best_quality"`를 사용한다. 다만 다수의 모델을 더 많이, 더 깊게 학습하므로 시간이 오래 소요된다.

# %%
predictor_best = TabularPredictor(
    label="Rented Bike Count"
).fit(train_data, 
      presets="best_quality", 
      fit_strategy="sequential",
      time_limit=600)

predictor_best.leaderboard(test_data)

# %% [markdown]
# #### 표 데이터용 파운데이션 모델
#
# AutoGluon에는 **표(정형) 데이터 전용 파운데이션 모델**도 포함되어 있다. 대표적으로 **TabPFNv2**와 **Mitra**가 있으며, 대량의 표 데이터로 사전학습되어 있어 별도의 장시간 학습 없이도 예측이 가능하다. 특히 데이터 규모가 작을 때 우수한 성능을 보인다.
#
# 사용 시 유의사항은 다음과 같다.
#
# - **GPU가 필요하다.** 신경망 기반이므로 CPU에서는 학습 속도가 매우 느리다.
# - **별도 설치가 필요하다.** 기본 설치에는 포함되어 있지 않다.
# - **회귀 문제**(따릉이 대여량 예측 등)에서는 `TabPFNv2`, `Mitra`를 사용할 수 있다. (`TabICL`은 분류 전용이다.)

# %%
# !{sys.executable} -m pip install tabpfn
# !pip install omegaconf
# !pip install autogluon.tabular[mitra]   # For Mitra
# !pip install autogluon.tabular[tabicl]   # For TabICL
# !pip install autogluon.tabular[tabpfn]   # For TabPFNv2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: omegaconf in /home/work/.local/lib/python3.10/site-packages (2.3.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/work/.local/lib/python3.10/site-packages (from omegaconf) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf) (6.0.2)
# WARNING: Error parsing dependencies of devscripts: Invalid version: '2.22.1ubuntu1'
#
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: autogluon.tabular[mitra] in /home/work/.local/lib/python3.10/site-packages (1.5.0)
# Requirement already satisfied: numpy<2.4.0,>=1.25.0 in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[mitra]) (1.26.4)
# Requirement already satisfied: scipy<1.17,>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular[mitra]) (1.14.0)
# Requirement already satisfied: pandas<2.4.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular[mitra]) (2.2.2)
# Requirement already satisfied: scikit-learn<1.8.0,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular[mitra]) (1.5.1)
# Requirement already satisfied: networkx<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular[mitra]) (3.3)
# Requirement already satisfied: autogluon.core==1.5.0 in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[mitra]) (1.5.0)
# Requirement already satisfied: autogluon.features==1.5.0 in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[mitra]) (1.5.0)
# Requirement already satisfied: loguru in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[mitra]) (0.7.3)
# Requirement already satisfied: einx in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[mitra]) (0.4.3)
# Requirement already satisfied: omegaconf in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[mitra]) (2.3.1)
# Requirement already satisfied: torch<2.10,>=2.6 in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[mitra]) (2.9.1)
# Requirement already satisfied: transformers in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[mitra]) (4.57.6)
# Requirement already satisfied: huggingface_hub<1.0 in /home/work/.local/lib/python3.10/site-packages (from huggingface_hub[torch]<1.0; extra == "mitra"->autogluon.tabular[mitra]) (0.36.2)
# Requirement already satisfied: einops<0.9,>=0.7 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular[mitra]) (0.8.0)
# Requirement already satisfied: tqdm<5,>=4.38 in /usr/local/lib/python3.10/dist-packages (from autogluon.core==1.5.0->autogluon.tabular[mitra]) (4.66.5)
# Requirement already satisfied: requests in /home/work/.local/lib/python3.10/site-packages (from autogluon.core==1.5.0->autogluon.tabular[mitra]) (2.34.2)
# Requirement already satisfied: matplotlib<3.11,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.core==1.5.0->autogluon.tabular[mitra]) (3.9.2)
# Requirement already satisfied: boto3<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from autogluon.core==1.5.0->autogluon.tabular[mitra]) (1.27.1)
# Requirement already satisfied: autogluon.common==1.5.0 in /home/work/.local/lib/python3.10/site-packages (from autogluon.core==1.5.0->autogluon.tabular[mitra]) (1.5.0)
# Requirement already satisfied: pyarrow<21.0.0,>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular[mitra]) (16.1.0)
# Requirement already satisfied: psutil<7.2.0,>=5.7.3 in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular[mitra]) (6.0.0)
# Requirement already satisfied: joblib<1.7,>=1.2 in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular[mitra]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular[mitra]) (6.0.2)
# Requirement already satisfied: filelock in /home/work/.local/lib/python3.10/site-packages (from huggingface_hub<1.0->huggingface_hub[torch]<1.0; extra == "mitra"->autogluon.tabular[mitra]) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0->huggingface_hub[torch]<1.0; extra == "mitra"->autogluon.tabular[mitra]) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/work/.local/lib/python3.10/site-packages (from huggingface_hub<1.0->huggingface_hub[torch]<1.0; extra == "mitra"->autogluon.tabular[mitra]) (1.5.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0->huggingface_hub[torch]<1.0; extra == "mitra"->autogluon.tabular[mitra]) (23.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/work/.local/lib/python3.10/site-packages (from huggingface_hub<1.0->huggingface_hub[torch]<1.0; extra == "mitra"->autogluon.tabular[mitra]) (4.16.0)
# Requirement already satisfied: safetensors[torch] in /usr/local/lib/python3.10/dist-packages (from huggingface_hub[torch]<1.0; extra == "mitra"->autogluon.tabular[mitra]) (0.4.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular[mitra]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular[mitra]) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular[mitra]) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.8.0,>=1.4.0->autogluon.tabular[mitra]) (3.5.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/work/.local/lib/python3.10/site-packages (from torch<2.10,>=2.6->autogluon.tabular[mitra]) (3.5.1)
# Requirement already satisfied: frozendict in /home/work/.local/lib/python3.10/site-packages (from einx->autogluon.tabular[mitra]) (2.4.7)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/work/.local/lib/python3.10/site-packages (from omegaconf->autogluon.tabular[mitra]) (4.9.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->autogluon.tabular[mitra]) (2024.7.24)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/work/.local/lib/python3.10/site-packages (from transformers->autogluon.tabular[mitra]) (0.22.2)
# Requirement already satisfied: botocore<1.31.0,>=1.30.1 in /usr/local/lib/python3.10/dist-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular[mitra]) (1.30.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular[mitra]) (0.9.4)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular[mitra]) (0.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[mitra]) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[mitra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[mitra]) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[mitra]) (1.4.6)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[mitra]) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[mitra]) (3.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=2.0.0->autogluon.tabular[mitra]) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.13.3->torch<2.10,>=2.6->autogluon.tabular[mitra]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/work/.local/lib/python3.10/site-packages (from jinja2->torch<2.10,>=2.6->autogluon.tabular[mitra]) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autogluon.core==1.5.0->autogluon.tabular[mitra]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/work/.local/lib/python3.10/site-packages (from requests->autogluon.core==1.5.0->autogluon.tabular[mitra]) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from requests->autogluon.core==1.5.0->autogluon.tabular[mitra]) (1.26.20)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.10/dist-packages (from requests->autogluon.core==1.5.0->autogluon.tabular[mitra]) (2024.8.30)
# WARNING: Error parsing dependencies of devscripts: Invalid version: '2.22.1ubuntu1'
#
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: autogluon.tabular[tabicl] in /home/work/.local/lib/python3.10/site-packages (1.5.0)
# Requirement already satisfied: numpy<2.4.0,>=1.25.0 in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[tabicl]) (1.26.4)
# Requirement already satisfied: scipy<1.17,>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular[tabicl]) (1.14.0)
# Requirement already satisfied: pandas<2.4.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular[tabicl]) (2.2.2)
# Requirement already satisfied: scikit-learn<1.8.0,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular[tabicl]) (1.5.1)
# Requirement already satisfied: networkx<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular[tabicl]) (3.3)
# Requirement already satisfied: autogluon.core==1.5.0 in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[tabicl]) (1.5.0)
# Requirement already satisfied: autogluon.features==1.5.0 in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[tabicl]) (1.5.0)
# Requirement already satisfied: tabicl<0.2,>=0.1.4 in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[tabicl]) (0.1.4)
# Requirement already satisfied: tqdm<5,>=4.38 in /usr/local/lib/python3.10/dist-packages (from autogluon.core==1.5.0->autogluon.tabular[tabicl]) (4.66.5)
# Requirement already satisfied: requests in /home/work/.local/lib/python3.10/site-packages (from autogluon.core==1.5.0->autogluon.tabular[tabicl]) (2.34.2)
# Requirement already satisfied: matplotlib<3.11,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.core==1.5.0->autogluon.tabular[tabicl]) (3.9.2)
# Requirement already satisfied: boto3<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from autogluon.core==1.5.0->autogluon.tabular[tabicl]) (1.27.1)
# Requirement already satisfied: autogluon.common==1.5.0 in /home/work/.local/lib/python3.10/site-packages (from autogluon.core==1.5.0->autogluon.tabular[tabicl]) (1.5.0)
# Requirement already satisfied: pyarrow<21.0.0,>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (16.1.0)
# Requirement already satisfied: psutil<7.2.0,>=5.7.3 in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (6.0.0)
# Requirement already satisfied: joblib<1.7,>=1.2 in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular[tabicl]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular[tabicl]) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular[tabicl]) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.8.0,>=1.4.0->autogluon.tabular[tabicl]) (3.5.0)
# Requirement already satisfied: einops>=0.7 in /usr/local/lib/python3.10/dist-packages (from tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (0.8.0)
# Requirement already satisfied: huggingface-hub in /home/work/.local/lib/python3.10/site-packages (from tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (0.36.2)
# Requirement already satisfied: torch<3,>=2.2 in /home/work/.local/lib/python3.10/site-packages (from tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (2.9.1)
# Requirement already satisfied: transformers in /home/work/.local/lib/python3.10/site-packages (from tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (4.57.6)
# Requirement already satisfied: wandb in /home/work/.local/lib/python3.10/site-packages (from tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (0.28.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (2.1.1)
# Requirement already satisfied: botocore<1.31.0,>=1.30.1 in /usr/local/lib/python3.10/dist-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (1.30.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (0.9.4)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (0.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (1.4.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (3.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=2.0.0->autogluon.tabular[tabicl]) (1.16.0)
# Requirement already satisfied: filelock in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (3.29.7)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (4.16.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.10/dist-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (3.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/work/.local/lib/python3.10/site-packages (from huggingface-hub->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (1.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/work/.local/lib/python3.10/site-packages (from requests->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from requests->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (1.26.20)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.10/dist-packages (from requests->autogluon.core==1.5.0->autogluon.tabular[tabicl]) (2024.8.30)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (2024.7.24)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/work/.local/lib/python3.10/site-packages (from transformers->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from transformers->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (0.4.5)
# Requirement already satisfied: click>=8.2.0 in /home/work/.local/lib/python3.10/site-packages (from wandb->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (8.4.2)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (3.1.26)
# Requirement already satisfied: platformdirs in /home/work/.local/lib/python3.10/site-packages (from wandb->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (4.10.0)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /home/work/.local/lib/python3.10/site-packages (from wandb->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (7.35.1)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.10/dist-packages (from wandb->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (2.8.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/work/.local/lib/python3.10/site-packages (from wandb->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (2.64.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (4.0.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.6->wandb->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.6->wandb->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (2.20.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.13.3->torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/work/.local/lib/python3.10/site-packages (from jinja2->torch<3,>=2.2->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (3.0.3)
# Requirement already satisfied: smmap<4,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->tabicl<0.2,>=0.1.4->autogluon.tabular[tabicl]) (3.0.5)
# WARNING: Error parsing dependencies of devscripts: Invalid version: '2.22.1ubuntu1'
#
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: autogluon.tabular[tabpfn] in /home/work/.local/lib/python3.10/site-packages (1.5.0)
# Requirement already satisfied: numpy<2.4.0,>=1.25.0 in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[tabpfn]) (1.26.4)
# Requirement already satisfied: scipy<1.17,>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular[tabpfn]) (1.14.0)
# Requirement already satisfied: pandas<2.4.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular[tabpfn]) (2.2.2)
# Requirement already satisfied: scikit-learn<1.8.0,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular[tabpfn]) (1.5.1)
# Requirement already satisfied: networkx<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.tabular[tabpfn]) (3.3)
# Requirement already satisfied: autogluon.core==1.5.0 in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[tabpfn]) (1.5.0)
# Requirement already satisfied: autogluon.features==1.5.0 in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[tabpfn]) (1.5.0)
# Requirement already satisfied: tabpfn<6.2.1,>=6.2.0 in /home/work/.local/lib/python3.10/site-packages (from autogluon.tabular[tabpfn]) (6.2.0)
# Requirement already satisfied: tqdm<5,>=4.38 in /usr/local/lib/python3.10/dist-packages (from autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (4.66.5)
# Requirement already satisfied: requests in /home/work/.local/lib/python3.10/site-packages (from autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (2.34.2)
# Requirement already satisfied: matplotlib<3.11,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (3.9.2)
# Requirement already satisfied: boto3<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (1.27.1)
# Requirement already satisfied: autogluon.common==1.5.0 in /home/work/.local/lib/python3.10/site-packages (from autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (1.5.0)
# Requirement already satisfied: pyarrow<21.0.0,>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (16.1.0)
# Requirement already satisfied: psutil<7.2.0,>=5.7.3 in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (6.0.0)
# Requirement already satisfied: joblib<1.7,>=1.2 in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.0 in /usr/local/lib/python3.10/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular[tabpfn]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular[tabpfn]) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular[tabpfn]) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.8.0,>=1.4.0->autogluon.tabular[tabpfn]) (3.5.0)
# Requirement already satisfied: torch<3,>=2.1 in /home/work/.local/lib/python3.10/site-packages (from tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (2.9.1)
# Requirement already satisfied: typing_extensions>=4.12.0 in /home/work/.local/lib/python3.10/site-packages (from tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (4.16.0)
# Requirement already satisfied: einops<0.9,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (0.8.0)
# Requirement already satisfied: huggingface-hub<2,>=0.19.0 in /home/work/.local/lib/python3.10/site-packages (from tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (0.36.2)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (2.8.2)
# Requirement already satisfied: pydantic-settings>=2.10.1 in /home/work/.local/lib/python3.10/site-packages (from tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (2.14.2)
# Requirement already satisfied: eval-type-backport>=0.2.2 in /home/work/.local/lib/python3.10/site-packages (from tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (0.4.0)
# Requirement already satisfied: tabpfn-common-utils>=0.2.8 in /home/work/.local/lib/python3.10/site-packages (from tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (0.2.23)
# Requirement already satisfied: botocore<1.31.0,>=1.30.1 in /usr/local/lib/python3.10/dist-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (1.30.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (0.9.4)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (0.6.1)
# Requirement already satisfied: filelock in /home/work/.local/lib/python3.10/site-packages (from huggingface-hub<2,>=0.19.0->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/work/.local/lib/python3.10/site-packages (from huggingface-hub<2,>=0.19.0->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (1.5.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (1.4.6)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (3.1.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.8.0->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.8.0->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/work/.local/lib/python3.10/site-packages (from pydantic-settings>=2.10.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (1.2.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/work/.local/lib/python3.10/site-packages (from pydantic-settings>=2.10.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=2.0.0->autogluon.tabular[tabpfn]) (1.16.0)
# Requirement already satisfied: nvidia-ml-py>=13.590.48 in /home/work/.local/lib/python3.10/site-packages (from tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (13.610.43)
# Requirement already satisfied: platformdirs>=4 in /home/work/.local/lib/python3.10/site-packages (from tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (4.10.0)
# Requirement already satisfied: posthog>=6.7 in /home/work/.local/lib/python3.10/site-packages (from tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (7.22.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/work/.local/lib/python3.10/site-packages (from requests->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from requests->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (1.26.20)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.10/dist-packages (from requests->autogluon.core==1.5.0->autogluon.tabular[tabpfn]) (2024.8.30)
# Requirement already satisfied: sympy>=1.13.3 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/work/.local/lib/python3.10/site-packages (from torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (3.5.1)
# Requirement already satisfied: backoff>=1.10.0 in /home/work/.local/lib/python3.10/site-packages (from posthog>=6.7->tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /home/work/.local/lib/python3.10/site-packages (from posthog>=6.7->tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (1.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.13.3->torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/work/.local/lib/python3.10/site-packages (from jinja2->torch<3,>=2.1->tabpfn<6.2.1,>=6.2.0->autogluon.tabular[tabpfn]) (3.0.3)
# WARNING: Error parsing dependencies of devscripts: Invalid version: '2.22.1ubuntu1'
#
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python -m pip install --upgrade pip

# %%
predictor_fm = TabularPredictor(label="Rented Bike Count").fit(
    train_data,
    hyperparameters={
        "REALTABPFN-V2": {},   # 소규모 데이터에 강한 파운데이션 모델
        "MITRA": {},      # AutoGluon의 표 데이터 파운데이션 모델
    },
    num_gpus=1,
    num_cpus=16,
    verbosity=2
)

predictor_fm.leaderboard(test_data)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20260713_071122"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.5.0
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #191-Ubuntu SMP Fri Feb 2 13:55:07 UTC 2024
# CPU Count:          18
# Pytorch Version:    2.9.1+cu128
# CUDA Version:       12.8
# GPU Memory:         GPU 0: 24.00/24.00 GB
# Total GPU Memory:   Free: 24.00 GB, Allocated: 0.00 GB, Total: 24.00 GB
# GPU Count:          1
# Memory Avail:       945.89 GB / 1007.45 GB (93.9%)
# Disk Space Avail:   420249.30 GB / 1080179.50 GB (38.9%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='extreme'  : New in v1.5: The state-of-the-art for tabular data. Massively better than 'best' on datasets <100000 samples by using new Tabular Foundation Models (TFMs) meta-learned on https://tabarena.ai: TabPFNv2, TabICL, Mitra, TabDPT, and TabM. Requires a GPU and `pip install autogluon.tabular[tabarena]` to install TabPFN, TabICL, and TabDPT.
# 	presets='best'     : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='best_v150': New in v1.5: Better quality than 'best' and 5x+ faster to train. Give it a try!
# 	presets='high'     : Strong accuracy with fast inference speed.
# 	presets='high_v150': New in v1.5: Better quality than 'high' and 5x+ faster to train. Give it a try!
# 	presets='good'     : Good accuracy with very fast inference speed.
# 	presets='medium'   : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ...
# AutoGluon will save models to "/workspace/SKKU/AutogluonModels/ag-20260713_071122"
# Train Data Rows:    7008
# Train Data Columns: 13
# Label Column:       Rented Bike Count
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == int and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (3556, 0, 706.56436, 644.72501)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    968590.58 MB
# 	Train Data (Original)  Memory Usage: 1.80 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('datetime', []) : 1 | ['Date']
# 		('float', [])    : 6 | ['Temperature(°C)', 'Wind speed (m/s)', 'Dew point temperature(°C)', 'Solar Radiation (MJ/m2)', 'Rainfall(mm)', ...]
# 		('int', [])      : 3 | ['Hour', 'Humidity(%)', 'Visibility (10m)']
# 		('object', [])   : 3 | ['Seasons', 'Holiday', 'Functioning Day']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])             : 1 | ['Seasons']
# 		('float', [])                : 6 | ['Temperature(°C)', 'Wind speed (m/s)', 'Dew point temperature(°C)', 'Solar Radiation (MJ/m2)', 'Rainfall(mm)', ...]
# 		('int', [])                  : 3 | ['Hour', 'Humidity(%)', 'Visibility (10m)']
# 		('int', ['bool'])            : 2 | ['Holiday', 'Functioning Day']
# 		('int', ['datetime_as_int']) : 5 | ['Date', 'Date.year', 'Date.month', 'Date.day', 'Date.dayofweek']
# 	0.1s = Fit runtime
# 	13 features in original data used to generate 17 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.77 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.08s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 6307, Val Rows: 701
# User-specified model hyperparameters to be fit:
# {
# 	'REALTABPFN-V2': [{}],
# 	'MITRA': [{}],
# }
# Fitting 2 L1 models, fit_strategy="sequential" ...
# Fitting model: Mitra ...
# 	Fitting with cpus=16, gpus=1, mem=12.3/945.9 GB
# 	-136.2029	 = Validation score   (-root_mean_squared_error)
# 	118.09s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: RealTabPFN-v2 ...
# 	Fitting with cpus=16, gpus=1, mem=1.3/944.1 GB
# 	Built with PriorLabs-TabPFN
# 	-110.6696	 = Validation score   (-root_mean_squared_error)
# 	1.4s	 = Training   runtime
# 	1.55s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Fitting 1 model on all data | Fitting with cpus=16, gpus=1, mem=0.0/943.9 GB
# 	Ensemble Weights: {'RealTabPFN-v2': 1.0}
# 	-110.6696	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 122.22s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 452.6 rows/s (701 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/workspace/SKKU/AutogluonModels/ag-20260713_071122")
#                  model  score_test   score_val              eval_metric  \
# 0        RealTabPFN-v2 -119.870816 -110.669610  root_mean_squared_error
# 1  WeightedEnsemble_L2 -119.870816 -110.669610  root_mean_squared_error
# 2                Mitra -143.891143 -136.202876  root_mean_squared_error
#
#    pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0        1.852436       1.548545    1.397396                 1.852436
# 1        1.854492       1.548877    1.403705                 0.002055
# 2        1.249038       0.520610  118.087708                 1.249038
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                1.548545           1.397396            1       True
# 1                0.000331           0.006309            2       True
# 2                0.520610         118.087708            1       True
#
#    fit_order
# 0          2
# 1          3
# 2          1

# %% [markdown]
# ---
# ## 6. 변수 중요도 확인: `feature_importance()`
#
# 어떤 변수가 예측에 큰 영향을 미쳤는지 확인한다. 이는 모델의 예측 근거를 파악하는 과정으로, 연구에서 중요한 부분이다.

# %%
importance = predictor.feature_importance(test_data)
importance
# Out:
# Computing feature importance via permutation shuffling for 13 features using 1752 rows with 5 shuffle sets...
# 	30.85s	= Expected runtime (6.17s per shuffle set)
# 	2.83s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                            importance     stddev       p_value  n    p99_high  \
# Hour                       397.967208   8.311228  2.281395e-08  5  415.080142
# Temperature(°C)            235.492049   6.549999  7.174526e-08  5  248.978586
# Date                       175.026433   5.674466  1.323909e-07  5  186.710235
# Functioning Day            167.278369  12.116693  3.280397e-06  5  192.226806
# Solar Radiation (MJ/m2)    121.784338   4.208826  1.709103e-07  5  130.450369
# Humidity(%)                104.117337   1.843690  1.179394e-08  5  107.913520
# Rainfall(mm)                35.665821   6.142485  1.015233e-04  5   48.313284
# Dew point temperature(°C)   25.659546   1.736729  2.503026e-06  5   29.235495
# Seasons                     22.275584   1.105146  7.246344e-07  5   24.551094
# Holiday                     11.980162   2.364391  1.729748e-04  5   16.848475
# Visibility (10m)             5.273039   0.855363  8.025144e-05  5    7.034242
# Wind speed (m/s)             2.274676   0.389049  9.880205e-05  5    3.075732
# Snowfall (cm)                0.467625   0.120603  4.869212e-04  5    0.715949
#
#                               p99_low
# Hour                       380.854274
# Temperature(°C)            222.005511
# Date                       163.342630
# Functioning Day            142.329931
# Solar Radiation (MJ/m2)    113.118306
# Humidity(%)                100.321154
# Rainfall(mm)                23.018359
# Dew point temperature(°C)   22.083598
# Seasons                     20.000074
# Holiday                      7.111849
# Visibility (10m)             3.511835
# Wind speed (m/s)             1.473620
# Snowfall (cm)                0.219301

# %% [markdown]
# #### 결과 해석
#
# - `importance` 값이 **클수록 해당 변수가 예측에 더 중요**함을 의미한다.
# - 따릉이 데이터에서는 대체로 **`Hour`(시간)** 와 **`Temperature`(기온)** 의 중요도가 높게 나타난다. 이는 시간대와 기상 조건이 자전거 대여량을 결정하는 주요 요인임을 의미하며, 통념과도 부합한다.
# - 이처럼 변수 중요도를 통해 연구자는 모델의 예측 근거를 해석하고 설명할 수 있다.

# %% [markdown]
# ---
# ## 정리
#
# | 단계 | 명령 | 내용 |
# |---|---|---|
# | 학습 | `TabularPredictor(label=...).fit()` | 다수 모델 학습 + 앙상블 자동 구성 |
# | 성능 | `predictor.leaderboard(test)` | 모델별 성능 비교 (최상단이 최우수) |
# | 예측 | `predictor.predict(test)` | 최우수 모델로 예측 |
# | 설정 조절 | `presets`, `time_limit`, `eval_metric` | 성능·시간·평가기준을 연구자가 지정 |
# | 해석 | `predictor.feature_importance(test)` | 변수별 중요도 확인 |
#
# **요약:** `fit()` 단일 명령이 다수 모델의 학습과 앙상블을 자동으로 수행하며, 앙상블은 대체로 개별 모델보다 우수하다. 연구자는 결과(leaderboard, 변수 중요도)를 해석하고, 필요에 따라 설정(`presets`, `eval_metric`)을 조정한다. 특히 `eval_metric`은 연구 목적에 따라 결정되는 연구자의 판단 영역이다.
